# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.preprocessing import PowerTransformer

from sklearn.ensemble import RandomForestRegressor,  GradientBoostingRegressor
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
import lightgbm as lgb
# Out:
# /Users/shin/anaconda3/lib/python3.7/site-packages/lightgbm/__init__.py:48: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_8.3.3) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)

# %%
#データの読み込み
item_categories = pd.read_csv("item_categories.csv")
items = pd.read_csv("items.csv")
shops = pd.read_csv("shops.csv")
test = pd.read_csv("test.csv")
sample = pd.read_csv("sample_submission.csv")
sales_train = pd.read_csv("sales_train.csv")

# %%
# データを結合
train = sales_train.merge(items,how="left").merge(item_categories,how="left").merge(shops,how="left")
test = test.merge(items,how="left").drop("item_name",axis=1)

# %%
# testに含まれるデータを抽出する
test_shop_id = test["shop_id"].unique()
test_item_id = test["item_id"].unique()

# trainの中からtestにあるデータを抜き出す
train_lk = train[train["shop_id"].isin(test_shop_id)]
train_lk = train_lk[train_lk["item_id"].isin(test_item_id)]

# %%
# 月次のデータに変換する
train_monthly = train_lk.sort_values("date_block_num").groupby(
            ["shop_id","item_id","date_block_num","item_category_id"],as_index=False).agg(
                {"item_price":["sum","last","mean"],"item_cnt_day":["sum","mean","count"]})

# %%
train_monthly.columns = [
                "shop_id",
                "item_id",
                'date_block_num',
                'item_category_id',
                "item_price",
                'last_item_price', 
                'mean_item_price', 
                'sum_item_cnt', 
                'mean_item_cnt', 
                'count_item_cnt']

# %%
# 月×店舗×商品のテーブルを作成
train_shop_id = train_monthly["shop_id"].unique()
train_item_id =train_monthly["item_id"].unique()

df = []

for month in range(34):
    for shop in train_shop_id:
        for item in train_item_id:
            df.append([month,shop,item])
            
df= pd.DataFrame(df,columns=["date_block_num","shop_id","item_id"])
df.head()
# Out:
#    date_block_num  shop_id  item_id
# 0               0        2       30
# 1               0        2       31
# 2               0        2       32
# 3               0        2       33
# 4               0        2       53

# %%
#trainデータとマージしてNAはゼロで補完する
train_monthly = pd.merge(df,train_monthly,on=["date_block_num","item_id","shop_id"],how="left")

# %%
train_monthly.fillna(0,inplace=True)

# %%
train_monthly['year'] = train_monthly['date_block_num'].apply(lambda x: ((x//12) + 2013))
train_monthly['month'] = train_monthly['date_block_num'].apply(lambda x: (x % 12))

# %%
#時系列の売上個数をカウント
plt.figure(figsize=(20, 10))
plt.scatter(train_monthly["date_block_num"],train_monthly["sum_item_cnt"])
plt.xlabel("date_block_num")
plt.ylabel("item_cnt_day")
# Out:
# Text(0, 0.5, 'item_cnt_day')

# %%
#外れ値を除外
temp = train_monthly.sort_values(by="sum_item_cnt").reset_index(drop=True)

#0.1%タイルの位置
q001 = round(len(temp)*0.001)

#99.9%タイルの位置
q999 = round(len(temp)*0.999)

#上下0.5%を除いて抽出
train_monthly_leave_outlier = temp.iloc[q001:q999,:]

# %%
#時系列の売上個数をカウント
plt.figure(figsize=(20, 10))
plt.scatter(train_monthly_leave_outlier["date_block_num"],train_monthly_leave_outlier["sum_item_cnt"])
plt.xlabel("date_block_num")
plt.ylabel("item_cnt_day")
# Out:
# Text(0, 0.5, 'item_cnt_day')

# %% [markdown]
# ## 特徴量エンジニアリング

# %%
# ３ヶ月の移動平均を追加
train_monthly_leave_outlier["average_3month"] = train_monthly_leave_outlier.groupby(
                                                                            ['shop_id', 'item_id'])['sum_item_cnt'].apply(
                                                                                    lambda x: x.rolling(window=3,min_periods=1).mean().shift())
# Out:
# /Users/shin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
#商品1つあたりの平均価格を追加
train_monthly_leave_outlier['item_price_unit'] = train_monthly_leave_outlier['item_price'] // train_monthly_leave_outlier['count_item_cnt']
train_monthly_leave_outlier['item_price_unit'].fillna(0, inplace=True)
# Out:
# /Users/shin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/shin/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5434: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
#max価格とmin価格を追加
gp_item_price = train_monthly_leave_outlier.sort_values('date_block_num').groupby(['item_id'], as_index=False).agg({'item_price':[np.min, np.max]})
gp_item_price.columns = ['item_id', 'hist_min_item_price', 'hist_max_item_price']

train_monthly_leave_outlier = pd.merge(train_monthly_leave_outlier, gp_item_price, on='item_id', how='left')

# %%
#価格の変動量を追加
train_monthly_leave_outlier['price_increase'] = train_monthly_leave_outlier['item_price'] - train_monthly_leave_outlier['hist_min_item_price']
train_monthly_leave_outlier['price_decrease'] = train_monthly_leave_outlier['hist_max_item_price'] - train_monthly_leave_outlier['item_price']

# %% [markdown]
# ## validation

# %%
# validationの設定

#単純にhold-outで最後の１ヶ月分をvalidとする
train_monthly_leave_outlier = train_monthly_leave_outlier.sort_values(by="date_block_num").reset_index(drop=True)

valid = train_monthly_leave_outlier[train_monthly_leave_outlier["date_block_num"]==33]
train = train_monthly_leave_outlier[train_monthly_leave_outlier["date_block_num"] < 33]
#test_test = train_monthly_leave_outlier[train_monthly_leave_outlier["date_block_num"] == 33]

#29~33をvalid、3~28をtrainとする。最初の3ヶ月は移動平均がないので除外する
#train_monthly_leave_outlier = train_monthly_leave_outlier.sort_values(by="date_block_num").reset_index(drop=True)

# valid = train_monthly_leave_outlier[train_monthly_leave_outlier["date_block_num"] > 28]
# train = train_monthly_leave_outlier[train_monthly_leave_outlier["date_block_num"] < 29]

# %% [markdown]
# ## mean encoding

# %%
# Shop mean encoding.
gp_shop_mean = train.groupby(['shop_id']).agg({'sum_item_cnt': ['mean']})
gp_shop_mean.columns = ['shop_mean']
gp_shop_mean.reset_index(inplace=True)
# Item mean encoding.
gp_item_mean = train.groupby(['item_id']).agg({'sum_item_cnt': ['mean']})
gp_item_mean.columns = ['item_mean']
gp_item_mean.reset_index(inplace=True)
# Shop with item mean encoding.
gp_shop_item_mean = train.groupby(['shop_id', 'item_id']).agg({'sum_item_cnt': ['mean']})
gp_shop_item_mean.columns = ['shop_item_mean']
gp_shop_item_mean.reset_index(inplace=True)
# Year mean encoding.
gp_year_mean = train.groupby(['year']).agg({'sum_item_cnt': ['mean']})
gp_year_mean.columns = ['year_mean']
gp_year_mean.reset_index(inplace=True)
# Month mean encoding.
gp_month_mean = train.groupby(['month']).agg({'sum_item_cnt': ['mean']})
gp_month_mean.columns = ['month_mean']
gp_month_mean.reset_index(inplace=True)

# Add meand encoding features to train set.
train = pd.merge(train, gp_shop_mean, on=['shop_id'], how='left')
train = pd.merge(train, gp_item_mean, on=['item_id'], how='left')
train = pd.merge(train, gp_shop_item_mean, on=['shop_id', 'item_id'], how='left')
train = pd.merge(train, gp_year_mean, on=['year'], how='left')
train = pd.merge(train, gp_month_mean, on=['month'], how='left')
# Add meand encoding features to validation set.
valid = pd.merge(valid, gp_shop_mean, on=['shop_id'], how='left')
valid = pd.merge(valid, gp_item_mean, on=['item_id'], how='left')
valid = pd.merge(valid, gp_shop_item_mean, on=['shop_id', 'item_id'], how='left')
valid = pd.merge(valid, gp_year_mean, on=['year'], how='left')
valid = pd.merge(valid, gp_month_mean, on=['month'], how='left')

# %%
# xとyに分割する
#train_x = train.drop(["sum_item_cnt","date_block_num"], axis=1)
train_x = train.drop(["sum_item_cnt"], axis=1)
train_y = train["sum_item_cnt"]
#valid_x = valid.drop(["sum_item_cnt","date_block_num"], axis=1)
valid_x = valid.drop(["sum_item_cnt"], axis=1)
valid_y = valid["sum_item_cnt"]

test_test_x = test_test.drop(["sum_item_cnt"], axis=1)
test_test_y = test_test["sum_item_cnt"]

# %%
train_x.columns
# Out:
# Index(['date_block_num', 'shop_id', 'item_id', 'item_category_id',
#        'item_price', 'last_item_price', 'mean_item_price', 'mean_item_cnt',
#        'count_item_cnt', 'year', 'month', 'average_3month', 'item_price_unit',
#        'hist_min_item_price', 'hist_max_item_price', 'price_increase',
#        'price_decrease', 'shop_mean', 'item_mean', 'shop_item_mean',
#        'year_mean', 'month_mean'],
#       dtype='object')

# %%
# testデータに特徴量を追加
latest_records = pd.concat([train, valid]).drop_duplicates(subset=['shop_id', 'item_id'], keep='last')
test_v2 = pd.merge(test, latest_records, on=['shop_id', 'item_id'], how='left', suffixes=['', '_'])
test_v2['year'] = 2015
test_v2['month'] = 9
test_v2.drop(['sum_item_cnt'], axis=1, inplace=True)
test_v2 = test_v2[train_x.columns]

test_test_x = pd.merge(test, latest_records, on=['shop_id', 'item_id'], how='left', suffixes=['', '_'])
test_test_x['year'] = 2015
test_test_x['month'] = 9
test_test_x.drop(['sum_item_cnt'], axis=1, inplace=True)
test_test_x = test_test_x[train_x.columns]

# %%
test_test_x.head()
# Out:
#    date_block_num  shop_id  item_id  item_category_id  item_price  \
# 0            33.0        5     5037                19         0.0
# 1             NaN        5     5320                55         NaN
# 2            33.0        5     5233                19      1199.0
# 3            33.0        5     5232                23         0.0
# 4             NaN        5     5268                20         NaN
#
#    last_item_price  mean_item_price  mean_item_cnt  count_item_cnt  year  \
# 0              0.0              0.0            0.0             0.0  2015
# 1              NaN              NaN            NaN             NaN  2015
# 2           1199.0           1199.0            1.0             1.0  2015
# 3              0.0              0.0            0.0             0.0  2015
# 4              NaN              NaN            NaN             NaN  2015
#
#       ...      item_price_unit  hist_min_item_price  hist_max_item_price  \
# 0     ...                  0.0                  0.0             25990.00
# 1     ...                  NaN                  NaN                  NaN
# 2     ...               1199.0                  0.0              7191.75
# 3     ...                  0.0                  0.0              4796.00
# 4     ...                  NaN                  NaN                  NaN
#
#    price_increase  price_decrease  shop_mean  item_mean  shop_item_mean  \
# 0             0.0        25990.00   0.129945   0.775525        0.393939
# 1             NaN             NaN        NaN        NaN             NaN
# 2          1199.0         5992.75   0.129945   0.322022        0.272727
# 3             0.0         4796.00   0.129945   0.080866        0.030303
# 4             NaN             NaN        NaN        NaN             NaN
#
#    year_mean  month_mean
# 0   0.237646    0.167781
# 1        NaN         NaN
# 2   0.237646    0.167781
# 3   0.237646    0.167781
# 4        NaN         NaN
#
# [5 rows x 22 columns]

# %%
test_v2.head()
# Out:
#    date_block_num  shop_id  item_id  item_category_id  item_price  \
# 0            33.0        5     5037                19         0.0
# 1             NaN        5     5320                55         NaN
# 2            33.0        5     5233                19      1199.0
# 3            33.0        5     5232                23         0.0
# 4             NaN        5     5268                20         NaN
#
#    last_item_price  mean_item_price  mean_item_cnt  count_item_cnt  year  \
# 0              0.0              0.0            0.0             0.0  2015
# 1              NaN              NaN            NaN             NaN  2015
# 2           1199.0           1199.0            1.0             1.0  2015
# 3              0.0              0.0            0.0             0.0  2015
# 4              NaN              NaN            NaN             NaN  2015
#
#       ...      item_price_unit  hist_min_item_price  hist_max_item_price  \
# 0     ...                  0.0                  0.0             25990.00
# 1     ...                  NaN                  NaN                  NaN
# 2     ...               1199.0                  0.0              7191.75
# 3     ...                  0.0                  0.0              4796.00
# 4     ...                  NaN                  NaN                  NaN
#
#    price_increase  price_decrease  shop_mean  item_mean  shop_item_mean  \
# 0             0.0        25990.00   0.129945   0.775525        0.393939
# 1             NaN             NaN        NaN        NaN             NaN
# 2          1199.0         5992.75   0.129945   0.322022        0.272727
# 3             0.0         4796.00   0.129945   0.080866        0.030303
# 4             NaN             NaN        NaN        NaN             NaN
#
#    year_mean  month_mean
# 0   0.237646    0.167781
# 1        NaN         NaN
# 2   0.237646    0.167781
# 3   0.237646    0.167781
# 4        NaN         NaN
#
# [5 rows x 22 columns]

# %%
#カテゴリIDは削除する
# train.drop(['item_category_id'], axis=1, inplace=True)
# valid.drop(['item_category_id'], axis=1, inplace=True)
# test_v2.drop(['item_category_id'], axis=1, inplace=True)

# %% [markdown]
# ## モデリング

# %% [markdown]
# ### lightGBM

# %%
#データセットを生成する
lgb_train = lgb.Dataset(train_x, train_y)
lgb_eval = lgb.Dataset(valid_x, valid_y, reference=lgb_train)

#LightGBM のハイパーパラメータ
lgb_params = {
        'objective': 'regression',
        'num_leaves': 10,
        'learning_rate': 0.1, 
        'n_estimators': 500,
        'max_bin': 255, 
        'bagging_fraction': 0.75,
        'bagging_freq': 5, 
        'bagging_seed': 7,
        'feature_fraction': 0.2,
        'feature_fraction_seed': 7,
        'verbose': -1,
        'metric': 'rmse'
    }

lgb_evals_result = {}

# 上記のパラメータでモデルを学習する
lightgbm = lgb.train(
                    lgb_params, 
                    lgb_train, 
                    valid_sets=lgb_eval,
                    evals_result=lgb_evals_result,
                )

ypred = lightgbm.predict(train_x)
# Out:
# /Users/shin/anaconda3/lib/python3.7/site-packages/lightgbm/engine.py:148: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [1]	valid_0's rmse: 0.859686
# [2]	valid_0's rmse: 0.811537
# [3]	valid_0's rmse: 0.740177
# [4]	valid_0's rmse: 0.734415
# [5]	valid_0's rmse: 0.702776
# [6]	valid_0's rmse: 0.677665
# [7]	valid_0's rmse: 0.675034
# [8]	valid_0's rmse: 0.62756
# [9]	valid_0's rmse: 0.577064
# [10]	valid_0's rmse: 0.541188
# [11]	valid_0's rmse: 0.528409
# [12]	valid_0's rmse: 0.51597
# [13]	valid_0's rmse: 0.506526
# [14]	valid_0's rmse: 0.506098
# [15]	valid_0's rmse: 0.473636
# [16]	valid_0's rmse: 0.465269
# [17]	valid_0's rmse: 0.456298
# [18]	valid_0's rmse: 0.451959
# [19]	valid_0's rmse: 0.447518
# [20]	valid_0's rmse: 0.435653
# [21]	valid_0's rmse: 0.412739
# [500]	valid_0's rmse: 0.147102

# %%
#trainデータとの合致度を可視化
plt.subplots_adjust(wspace=0.4)
plt.scatter(train_y,lightgbm.predict(train_x))
plt.scatter(valid_y,lightgbm.predict(valid_x))

# %%
#trainデータとの合致度を可視化
plt.subplots_adjust(wspace=0.4)
plt.scatter(train_y,lightgbm.predict(train_x))
plt.scatter(valid_y,lightgbm.predict(valid_x))

# %% [markdown]
# ### XGBoost

# %%
#特徴量と目的変数をxgboostのデータ構造に変換する
dtrain = xgb.DMatrix(train_x, label=train_y)
dvalid = xgb.DMatrix(valid_x,label=valid_y)
# Out:
# /Users/shin/anaconda3/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# /Users/shin/anaconda3/lib/python3.7/site-packages/xgboost/core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \

# %%
#パラメータを指定してGBDT
num_round = 30
evallist = [(dvalid, 'eval'), (dtrain, 'train')]

evals_result = {}

#パラメータ
param = {
            'max_depth': 5,
            'eta': 0.1,
            'objective': 'reg:squarederror',
}

#学習の実行
bst = xgb.train(
                        param, dtrain,
                        num_round,
                        evallist,
                        evals_result=evals_result,
                        # 一定ラウンド回しても改善が見込めない場合は学習を打ち切る
                        early_stopping_rounds=100
                        )
# Out:
# [22:43:30] WARNING: src/learner.cc:686: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# [0]	eval-rmse:0.882741	train-rmse:0.843424
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
# Will train until train-rmse hasn't improved in 100 rounds.
# [1]	eval-rmse:0.800333	train-rmse:0.766802
# [2]	eval-rmse:0.726425	train-rmse:0.686281
# [3]	eval-rmse:0.660218	train-rmse:0.620139
# [4]	eval-rmse:0.600611	train-rmse:0.565215
# [5]	eval-rmse:0.547536	train-rmse:0.507764
# [6]	eval-rmse:0.500097	train-rmse:0.462601
# [7]	eval-rmse:0.457794	train-rmse:0.415334
# [8]	eval-rmse:0.420067	train-rmse:0.375398
# [9]	eval-rmse:0.386392	train-rmse:0.343709
# [10]	eval-rmse:0.356726	train-rmse:0.311836
# [11]	eval-rmse:0.330614	train-rmse:0.285528
# [12]	eval-rmse:0.307198	train-rmse:0.257652
# [13]	eval-rmse:0.286735	train-rmse:0.23643
# [14]	eval-rmse:0.268932	train-rmse:0.216349
# [15]	eval-rmse:0.253253	train-rmse:0.19784
# [16]	eval-rmse:0.23959	train-rmse:0.185058
# [17]	eval-rmse:0.227821	train-rmse:0.169025
# [18]	eval-rmse:0.217659	train-rmse:0.157008
# [19]	eval-rmse:0.208854	train-rmse:0.148211
# [20]	eval-rmse:0.200944	train-rmse:0.139794
# [21]	eval-rmse:0.194516	train-rmse:0.129634
# [22]	eval-rmse:0.189162	train-rmse:0.123793
# [23]	eval-rmse:0.184703	train-rmse:0.118802
# [24]	eval-rmse:0.179696	train-rmse:0.113228
# [25]	eval-rmse:0.175263	train-rmse:0.109089
# [26]	eval-rmse:0.172228	train-rmse:0.104629
# [27]	eval-rmse:0.169413	train-rmse:0.101586
# [28]	eval-rmse:0.167401	train-rmse:0.099454
# [29]	eval-rmse:0.165196	train-rmse:0.096017

# %%
#学習曲線を可視化する
plt.figure(figsize=(20, 10))
train_metric = evals_result['train']['rmse']
plt.plot(train_metric, label='train rmse')
eval_metric = evals_result['eval']['rmse']
plt.plot(eval_metric, label='eval rmse')
plt.grid()
plt.legend()
plt.xlabel('rounds')
plt.ylabel('rmse')
plt.show()

# %%
#特徴量ごとの重要度を可視化する
ax = xgb.plot_importance(bst)
fig = ax.figure

# %%
#trainデータとの合致度を可視化
plt.subplots_adjust(wspace=0.4)
plt.scatter(train_y,bst.predict(dtrain))
plt.scatter(valid_y,bst.predict(dvalid))

# %% [markdown]
# #### 予備テスト

# %%
from sklearn.metrics import mean_squared_error
test_test_pred = lightgbm.predict(test_test_x)
print(np.sqrt(mean_squared_error(test_test_y, test_test_pred)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-83f1dca27229> in <module>
#       1 from sklearn.metrics import mean_squared_error
#       2 test_test_pred = lightgbm.predict(test_test_x)
# ----> 3 print(np.sqrt(mean_squared_error(test_test_y, test_test_pred)))
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/metrics/regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput)
#     237     """
#     238     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 239         y_true, y_pred, multioutput)
#     240     check_consistent_length(y_true, y_pred, sample_weight)
#     241     output_errors = np.average((y_true - y_pred) ** 2, axis=0,
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/metrics/regression.py in _check_reg_targets(y_true, y_pred, multioutput)
#      73
#      74     """
# ---> 75     check_consistent_length(y_true, y_pred)
#      76     y_true = check_array(y_true, ensure_2d=False)
#      77     y_pred = check_array(y_pred, ensure_2d=False)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     233     if len(uniques) > 1:
#     234         raise ValueError("Found input variables with inconsistent numbers of"
# --> 235                          " samples: %r" % [int(l) for l in lengths])
#     236
#     237
#
# ValueError: Found input variables with inconsistent numbers of samples: [197865, 214200]

# %% [markdown]
# ## 提出用ファイルの作成

# %%
#testデータで実行
lightgbm.predict(test_v2)
# Out:
# array([0.40258798, 0.43877837, 1.01096156, ..., 0.31494004, 0.20566712,
#        0.33232105])

# %%
# 提出用ファイルの作成
my_submission = pd.DataFrame()
my_submission["Id"] = test["ID"]
my_submission["item_cnt_month"] =lightgbm.predict(test_v2)

# you could use any filename. We choose submission here
my_submission.to_csv('submission.csv', index=False)

# %%
my_submission
# Out:
#             Id  item_cnt_month
# 0            0        0.685767
# 1            1        0.506251
# 2            2        0.685767
# 3            3        0.626576
# 4            4        0.633529
# 5            5        0.626576
# 6            6        0.633529
# 7            7        0.506251
# 8            8        0.506251
# 9            9        0.633529
# 10          10        0.685361
# 11          11        0.637308
# 12          12        0.504860
# 13          13        0.630689
# 14          14        0.630689
# 15          15        0.689880
# 16          16        0.646209
# 17          17        0.504860
# 18          18        0.690004
# 19          19        0.637642
# 20          20        0.504860
# 21          21        0.689880
# 22          22        0.637395
# 23          23        0.689880
# 24          24        0.692582
# 25          25        0.637642
# 26          26        0.631029
# 27          27        0.677504
# 28          28        0.691780
# 29          29        0.691780
# ...        ...             ...
# 214170  214170        0.476527
# 214171  214171        0.670403
# 214172  214172        0.476527
# 214173  214173        0.141246
# 214174  214174        0.692922
# 214175  214175        0.631029
# 214176  214176        0.505121
# 214177  214177        0.175107
# 214178  214178        0.505121
# 214179  214179        0.769065
# 214180  214180        0.476527
# 214181  214181        0.619749
# 214182  214182        0.691780
# 214183  214183        0.505121
# 214184  214184        0.505121
# 214185  214185        0.476527
# 214186  214186        0.476527
# 214187  214187        0.690220
# 214188  214188        0.505121
# 214189  214189        0.442666
# 214190  214190        0.581344
# 214191  214191        0.631029
# 214192  214192        0.631029
# 214193  214193        0.429543
# 214194  214194        0.429543
# 214195  214195        0.478401
# 214196  214196        0.442666
# 214197  214197        0.478401
# 214198  214198        0.476527
# 214199  214199        0.575942
#
# [214200 rows x 2 columns]
