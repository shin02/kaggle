# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.preprocessing import PowerTransformer

from sklearn.ensemble import RandomForestRegressor,  GradientBoostingRegressor
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
import lightgbm as lgb
# Out:
# /Users/shin/anaconda3/lib/python3.7/site-packages/lightgbm/__init__.py:48: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_8.3.3) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)

# %%
#データの読み込み
item_categories = pd.read_csv("item_categories.csv")
items = pd.read_csv("items.csv")
shops = pd.read_csv("shops.csv")
test = pd.read_csv("test.csv")
sample = pd.read_csv("sample_submission.csv")
sales_train = pd.read_csv("sales_train.csv")

# %%
# データを結合
train = sales_train.merge(items,how="left").merge(item_categories,how="left").merge(shops,how="left")
test = test.merge(items,how="left").drop("item_name",axis=1)

# %%
# testに含まれるデータを抽出する
test_shop_id = test["shop_id"].unique()
test_item_id = test["item_id"].unique()

# trainの中からtestにあるデータを抜き出す
train_lk = train[train["shop_id"].isin(test_shop_id)]
train_lk = train_lk[train_lk["item_id"].isin(test_item_id)]

# %%
# 月次のデータに変換する
train_monthly = train_lk.sort_values("date_block_num").groupby(
            ["shop_id","item_id","date_block_num","item_category_id"],as_index=False).agg(
                {"item_price":["sum","last","mean"],"item_cnt_day":["sum","mean","count"]})

# %%
train_monthly.columns = [
                "shop_id",
                "item_id",
                'date_block_num',
                'item_category_id',
                "item_price",
                'last_item_price', 
                'mean_item_price', 
                'sum_item_cnt', 
                'mean_item_cnt', 
                'count_item_cnt']

# %%
# 月×店舗×商品のテーブルを作成
train_shop_id = train_monthly["shop_id"].unique()
train_item_id =train_monthly["item_id"].unique()

df = []

for month in range(34):
    for shop in train_shop_id:
        for item in train_item_id:
            df.append([month,shop,item])
            
df= pd.DataFrame(df,columns=["date_block_num","shop_id","item_id"])
df.head()
# Out:
#    date_block_num  shop_id  item_id
# 0               0        2       30
# 1               0        2       31
# 2               0        2       32
# 3               0        2       33
# 4               0        2       53

# %%
#trainデータとマージしてNAはゼロで補完する
train_monthly = pd.merge(df,train_monthly,on=["date_block_num","item_id","shop_id"],how="left")

# %%
train_monthly.fillna(0,inplace=True)

# %%
train_monthly['year'] = train_monthly['date_block_num'].apply(lambda x: ((x//12) + 2013))
train_monthly['month'] = train_monthly['date_block_num'].apply(lambda x: (x % 12))

# %%
#時系列の売上個数をカウント
plt.figure(figsize=(20, 10))
plt.scatter(train_monthly["date_block_num"],train_monthly["sum_item_cnt"])
plt.xlabel("date_block_num")
plt.ylabel("item_cnt_day")
# Out:
# Text(0, 0.5, 'item_cnt_day')

# %%
#外れ値を除外
temp = train_monthly.sort_values(by="sum_item_cnt").reset_index(drop=True)

#0.1%タイルの位置
q001 = round(len(temp)*0.001)

#99.9%タイルの位置
q999 = round(len(temp)*0.999)

#上下0.5%を除いて抽出
train_monthly_leave_outlier = temp.iloc[q001:q999,:]

# %%
#時系列の売上個数をカウント
plt.figure(figsize=(20, 10))
plt.scatter(train_monthly_leave_outlier["date_block_num"],train_monthly_leave_outlier["sum_item_cnt"])
plt.xlabel("date_block_num")
plt.ylabel("item_cnt_day")
# Out:
# Text(0, 0.5, 'item_cnt_day')

# %% [markdown]
# ## 特徴量エンジニアリング

# %%
# ３ヶ月の移動平均を追加
train_monthly_leave_outlier["average_3month"] = train_monthly_leave_outlier.groupby(
                                                                            ['shop_id', 'item_id'])['sum_item_cnt'].apply(
                                                                                    lambda x: x.rolling(window=3,min_periods=1).mean().shift())
# Out:
# /Users/shin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
#商品1つあたりの平均価格を追加
train_monthly_leave_outlier['item_price_unit'] = train_monthly_leave_outlier['item_price'] // train_monthly_leave_outlier['count_item_cnt']
train_monthly_leave_outlier['item_price_unit'].fillna(0, inplace=True)
# Out:
# /Users/shin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/shin/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5434: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
#max価格とmin価格を追加
gp_item_price = train_monthly_leave_outlier.sort_values('date_block_num').groupby(['item_id'], as_index=False).agg({'item_price':[np.min, np.max]})
gp_item_price.columns = ['item_id', 'hist_min_item_price', 'hist_max_item_price']

train_monthly_leave_outlier = pd.merge(train_monthly_leave_outlier, gp_item_price, on='item_id', how='left')

# %%
#価格の変動量を追加
train_monthly_leave_outlier['price_increase'] = train_monthly_leave_outlier['item_price'] - train_monthly_leave_outlier['hist_min_item_price']
train_monthly_leave_outlier['price_decrease'] = train_monthly_leave_outlier['hist_max_item_price'] - train_monthly_leave_outlier['item_price']

# %% [markdown]
# ## validation

# %%
# validationの設定

#単純にhold-outで最後の１ヶ月分をvalidとする
train_monthly_leave_outlier = train_monthly_leave_outlier.sort_values(by="date_block_num").reset_index(drop=True)

valid = train_monthly_leave_outlier[train_monthly_leave_outlier["date_block_num"]==32]
train = train_monthly_leave_outlier[train_monthly_leave_outlier["date_block_num"] < 31]
test_test = train_monthly_leave_outlier[train_monthly_leave_outlier["date_block_num"] == 33]

#29~33をvalid、3~28をtrainとする。最初の3ヶ月は移動平均がないので除外する
#train_monthly_leave_outlier = train_monthly_leave_outlier.sort_values(by="date_block_num").reset_index(drop=True)

# valid = train_monthly_leave_outlier[train_monthly_leave_outlier["date_block_num"] > 28]
# train = train_monthly_leave_outlier[train_monthly_leave_outlier["date_block_num"] < 29]

# xとyに分割する
#train_x = train.drop(["sum_item_cnt","date_block_num"], axis=1)
train_x = train.drop(["sum_item_cnt"], axis=1)
train_y = train["sum_item_cnt"]
#valid_x = valid.drop(["sum_item_cnt","date_block_num"], axis=1)
valid_x = valid.drop(["sum_item_cnt"], axis=1)
valid_y = valid["sum_item_cnt"]

test_test_x = test_test.drop(["sum_item_cnt"], axis=1)
test_test_y = test_test["sum_item_cnt"]

# %%
# testデータに特徴量を追加
test_v2 = pd.merge(test, train_monthly_leave_outlier, on=['shop_id', 'item_id'], how='left', suffixes=['', '_'])
test_v2['year'] = 2015
test_v2['month'] = 9
test_v2.drop(['sum_item_cnt'], axis=1, inplace=True)
#test_v2[int_features] = test_v2[int_features].astype('int32')
test_v2 = test_v2[train_x.columns]

# %% [markdown]
# ## mean encoding

# %% [markdown]
# ## モデリング

# %% [markdown]
# ### lightGBM

# %%
#データセットを生成する
lgb_train = lgb.Dataset(train_x, train_y)
lgb_eval = lgb.Dataset(valid_x, valid_y, reference=lgb_train)

#LightGBM のハイパーパラメータ
lgb_params = {
        'objective': 'regression',
        'num_leaves': 10,
        'learning_rate': 0.1, 
        'n_estimators': 1000,
        'max_bin': 255, 
# [937]	valid_0's rmse: 0.0716629
# [938]	valid_0's rmse: 0.071653
# [939]	valid_0's rmse: 0.0716195
# [940]	valid_0's rmse: 0.0716305
# [941]	valid_0's rmse: 0.0716223
# [942]	valid_0's rmse: 0.0716296
# [943]	valid_0's rmse: 0.0716309
# [944]	valid_0's rmse: 0.071321
# [945]	valid_0's rmse: 0.0713038
# [946]	valid_0's rmse: 0.0712985
# [947]	valid_0's rmse: 0.0712948
# [948]	valid_0's rmse: 0.0712947
# [949]	valid_0's rmse: 0.0712795
# [950]	valid_0's rmse: 0.071289
# [951]	valid_0's rmse: 0.0712778
# [952]	valid_0's rmse: 0.0712839
# [953]	valid_0's rmse: 0.071283
# [954]	valid_0's rmse: 0.0712638
# [955]	valid_0's rmse: 0.071222
# [956]	valid_0's rmse: 0.0712017
# [957]	valid_0's rmse: 0.071206
# [958]	valid_0's rmse: 0.0711976
# [959]	valid_0's rmse: 0.0711626
# [960]	valid_0's rmse: 0.0708592
# [961]	valid_0's rmse: 0.0708501
# [962]	valid_0's rmse: 0.0708462
# [963]	valid_0's rmse: 0.0708563
# [964]	valid_0's rmse: 0.0708567
# [965]	valid_0's rmse: 0.0708975
# [966]	valid_0's rmse: 0.0708685
# [967]	valid_0's rmse: 0.070864
# [968]	valid_0's rmse: 0.0708545
# [969]	valid_0's rmse: 0.0708487
# [970]	valid_0's rmse: 0.070836
# [971]	valid_0's rmse: 0.0708332
# [972]	valid_0's rmse: 0.0708271
# [973]	valid_0's rmse: 0.0708284
# [974]	valid_0's rmse: 0.0708309
# [975]	valid_0's rmse: 0.0708262
# [976]	valid_0's rmse: 0.0706948
# [977]	valid_0's rmse: 0.0706865
# [978]	valid_0's rmse: 0.0706887
# [979]	valid_0's rmse: 0.0706861
# [980]	valid_0's rmse: 0.0706861
# [981]	valid_0's rmse: 0.0706849
# [982]	valid_0's rmse: 0.0705057
# [983]	valid_0's rmse: 0.0704482
# [984]	valid_0's rmse: 0.0704544
# [985]	valid_0's rmse: 0.0704428
# [986]	valid_0's rmse: 0.0704359
# [987]	valid_0's rmse: 0.0704426
# [988]	valid_0's rmse: 0.0703636
# [989]	valid_0's rmse: 0.0703629
# [990]	valid_0's rmse: 0.0703653
# [991]	valid_0's rmse: 0.0703646
# [992]	valid_0's rmse: 0.0699579
# [993]	valid_0's rmse: 0.0699652
# [994]	valid_0's rmse: 0.069951
# [995]	valid_0's rmse: 0.0699505
# [996]	valid_0's rmse: 0.0699462
# [997]	valid_0's rmse: 0.069945
# [998]	valid_0's rmse: 0.0699291
# [999]	valid_0's rmse: 0.0699329
# [1000]	valid_0's rmse: 0.0699268

# %%
#trainデータとの合致度を可視化
plt.subplots_adjust(wspace=0.4)
plt.scatter(train_y,lightgbm.predict(train_x))
plt.scatter(valid_y,lightgbm.predict(valid_x))

# %%
#trainデータとの合致度を可視化
plt.subplots_adjust(wspace=0.4)
plt.scatter(train_y,lightgbm.predict(train_x))
plt.scatter(valid_y,lightgbm.predict(valid_x))

# %% [markdown]
# ### XGBoost

# %%
#特徴量と目的変数をxgboostのデータ構造に変換する
dtrain = xgb.DMatrix(train_x, label=train_y)
dvalid = xgb.DMatrix(valid_x,label=valid_y)
# Out:
# /Users/shin/anaconda3/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# /Users/shin/anaconda3/lib/python3.7/site-packages/xgboost/core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \

# %%
#パラメータを指定してGBDT
num_round = 100
evallist = [(dvalid, 'eval'), (dtrain, 'train')]

evals_result = {}

#パラメータ
param = {
            'max_depth': 5,
            'eta': 0.1,
            'objective': 'reg:squarederror',
}

#学習の実行
bst = xgb.train(
                        param, dtrain,
                        num_round,
                        evallist,
                        evals_result=evals_result,
                        # 一定ラウンド回しても改善が見込めない場合は学習を打ち切る
                        early_stopping_rounds=100
                        )
# Out:
# [20:57:03] WARNING: src/learner.cc:686: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# [0]	eval-rmse:0.880263	train-rmse:0.845688
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
# Will train until train-rmse hasn't improved in 100 rounds.
# [1]	eval-rmse:0.795941	train-rmse:0.769232
# [2]	eval-rmse:0.720297	train-rmse:0.689048
# [3]	eval-rmse:0.652912	train-rmse:0.622655
# [4]	eval-rmse:0.592117	train-rmse:0.566436
# [5]	eval-rmse:0.538184	train-rmse:0.509282
# [6]	eval-rmse:0.489441	train-rmse:0.464799
# [7]	eval-rmse:0.446257	train-rmse:0.417443
# [8]	eval-rmse:0.407368	train-rmse:0.377192
# [9]	eval-rmse:0.373196	train-rmse:0.345651
# [10]	eval-rmse:0.342416	train-rmse:0.314004
# [11]	eval-rmse:0.315376	train-rmse:0.286674
# [12]	eval-rmse:0.291617	train-rmse:0.259851
# [13]	eval-rmse:0.270461	train-rmse:0.238505
# [14]	eval-rmse:0.252538	train-rmse:0.218606
# [15]	eval-rmse:0.236361	train-rmse:0.200196
# [16]	eval-rmse:0.222329	train-rmse:0.187311
# [17]	eval-rmse:0.210223	train-rmse:0.171792
# [18]	eval-rmse:0.199241	train-rmse:0.159774
# [19]	eval-rmse:0.190435	train-rmse:0.150945
# [20]	eval-rmse:0.182492	train-rmse:0.142445
# [21]	eval-rmse:0.175598	train-rmse:0.132711
# [22]	eval-rmse:0.169759	train-rmse:0.126805
# [23]	eval-rmse:0.164857	train-rmse:0.121824
# [24]	eval-rmse:0.160709	train-rmse:0.116438
# [25]	eval-rmse:0.157071	train-rmse:0.112412
# [26]	eval-rmse:0.154231	train-rmse:0.108201
# [27]	eval-rmse:0.151489	train-rmse:0.105262
# [28]	eval-rmse:0.149341	train-rmse:0.103095
# [29]	eval-rmse:0.147325	train-rmse:0.100099
# [30]	eval-rmse:0.14568	train-rmse:0.098361
# [31]	eval-rmse:0.144529	train-rmse:0.097091
# [32]	eval-rmse:0.143505	train-rmse:0.095647
# [33]	eval-rmse:0.14265	train-rmse:0.094725
# [34]	eval-rmse:0.141905	train-rmse:0.093989
# [35]	eval-rmse:0.141082	train-rmse:0.093319
# [36]	eval-rmse:0.139839	train-rmse:0.092359
# [37]	eval-rmse:0.139026	train-rmse:0.091845
# [38]	eval-rmse:0.138635	train-rmse:0.091488
# [39]	eval-rmse:0.138119	train-rmse:0.091046
# [40]	eval-rmse:0.137358	train-rmse:0.090713
# [41]	eval-rmse:0.136732	train-rmse:0.090446
# [42]	eval-rmse:0.136496	train-rmse:0.090186
# [43]	eval-rmse:0.136127	train-rmse:0.08995
# [44]	eval-rmse:0.135658	train-rmse:0.089731
# [45]	eval-rmse:0.135389	train-rmse:0.089575
# [46]	eval-rmse:0.134558	train-rmse:0.089426
# [47]	eval-rmse:0.134145	train-rmse:0.08923
# [48]	eval-rmse:0.133986	train-rmse:0.089078
# [49]	eval-rmse:0.133756	train-rmse:0.088938
# [50]	eval-rmse:0.133684	train-rmse:0.088883
# [51]	eval-rmse:0.133383	train-rmse:0.088802
# [52]	eval-rmse:0.133176	train-rmse:0.088694
# [53]	eval-rmse:0.13248	train-rmse:0.088547
# [54]	eval-rmse:0.132467	train-rmse:0.088512
# [55]	eval-rmse:0.132396	train-rmse:0.088431
# [56]	eval-rmse:0.131854	train-rmse:0.088329
# [57]	eval-rmse:0.1318	train-rmse:0.088282
# [58]	eval-rmse:0.131418	train-rmse:0.088195
# [59]	eval-rmse:0.131263	train-rmse:0.088113
# [60]	eval-rmse:0.130866	train-rmse:0.087991
# [61]	eval-rmse:0.130849	train-rmse:0.087841
# [62]	eval-rmse:0.130575	train-rmse:0.08766
# [63]	eval-rmse:0.13025	train-rmse:0.087585
# [64]	eval-rmse:0.130232	train-rmse:0.087556
# [65]	eval-rmse:0.130218	train-rmse:0.087521
# [66]	eval-rmse:0.130178	train-rmse:0.087505
# [67]	eval-rmse:0.130174	train-rmse:0.087471
# [68]	eval-rmse:0.129787	train-rmse:0.087232
# [69]	eval-rmse:0.129706	train-rmse:0.087193
# [70]	eval-rmse:0.129705	train-rmse:0.087183
# [71]	eval-rmse:0.129713	train-rmse:0.087173
# [72]	eval-rmse:0.129676	train-rmse:0.087124
# [73]	eval-rmse:0.129704	train-rmse:0.087082
# [74]	eval-rmse:0.1297	train-rmse:0.087036
# [75]	eval-rmse:0.129678	train-rmse:0.08703
# [76]	eval-rmse:0.129673	train-rmse:0.087018
# [77]	eval-rmse:0.129677	train-rmse:0.087011
# [78]	eval-rmse:0.129511	train-rmse:0.086915
# [79]	eval-rmse:0.129409	train-rmse:0.086792
# [80]	eval-rmse:0.129411	train-rmse:0.086782
# [81]	eval-rmse:0.129355	train-rmse:0.08671
# [82]	eval-rmse:0.129344	train-rmse:0.0867
# [83]	eval-rmse:0.129348	train-rmse:0.086692
# [84]	eval-rmse:0.129349	train-rmse:0.086686
# [85]	eval-rmse:0.12927	train-rmse:0.0866
# [86]	eval-rmse:0.129328	train-rmse:0.086539
# [87]	eval-rmse:0.129313	train-rmse:0.086504
# [88]	eval-rmse:0.129306	train-rmse:0.086497
# [89]	eval-rmse:0.129298	train-rmse:0.086489
# [90]	eval-rmse:0.129318	train-rmse:0.086451
# [91]	eval-rmse:0.129322	train-rmse:0.086415
# [92]	eval-rmse:0.129305	train-rmse:0.086408
# [93]	eval-rmse:0.129309	train-rmse:0.086381
# [94]	eval-rmse:0.129317	train-rmse:0.086337
# [95]	eval-rmse:0.129279	train-rmse:0.086284
# [96]	eval-rmse:0.129317	train-rmse:0.086224
# [97]	eval-rmse:0.129338	train-rmse:0.086205
# [98]	eval-rmse:0.129358	train-rmse:0.086065
# [99]	eval-rmse:0.129339	train-rmse:0.086017

# %%
#学習曲線を可視化する
plt.figure(figsize=(20, 10))
train_metric = evals_result['train']['rmse']
plt.plot(train_metric, label='train rmse')
eval_metric = evals_result['eval']['rmse']
plt.plot(eval_metric, label='eval rmse')
plt.grid()
plt.legend()
plt.xlabel('rounds')
plt.ylabel('rmse')
plt.show()

# %%
#特徴量ごとの重要度を可視化する
ax = xgb.plot_importance(bst)
fig = ax.figure

# %%
#trainデータとの合致度を可視化
plt.subplots_adjust(wspace=0.4)
plt.scatter(train_y,bst.predict(dtrain))
plt.scatter(valid_y,bst.predict(dvalid))

# %% [markdown]
# #### 予備テスト

# %%
from sklearn.metrics import mean_squared_error
test_test_pred = lightgbm.predict(test_test_x)
print(np.sqrt(mean_squared_error(test_test_y, test_test_pred)))
# Out:
# 0.06436450475383833

# %% [markdown]
# ## 提出用ファイルの作成

# %%
#testデータで実行
lightgbm.predict(test_v2)
# Out:
# array([0.31570408, 0.31570408, 0.31570408, ..., 0.26506671, 0.26506671,
#        0.26506671])

# %%
# 提出用ファイルの作成
my_submission = pd.DataFrame()
my_submission["Id"] = test["ID"]
my_submission["item_cnt_month"] =lightgbm.predict(test)

# you could use any filename. We choose submission here
my_submission.to_csv('submission.csv', index=False)

# %%
my_submission
# Out:
#             Id  item_cnt_month
# 0            0        0.300522
# 1            1        0.243243
# 2            2        0.300522
# 3            3        0.293864
# 4            4        0.300522
# 5            5        0.293864
# 6            6        0.300522
# 7            7        0.243243
# 8            8        0.243243
# 9            9        0.300522
# 10          10        0.395207
# 11          11        0.300902
# 12          12        0.243623
# 13          13        0.294245
# 14          14        0.294245
# 15          15        0.300902
# 16          16        0.285033
# 17          17        0.243623
# 18          18        0.372156
# 19          19        0.300902
# 20          20        0.243623
# 21          21        0.300902
# 22          22        0.389360
# 23          23        0.300902
# 24          24        0.356057
# 25          25        0.284740
# 26          26        0.284740
# 27          27        0.284740
# 28          28        0.284740
# 29          29        0.284740
# ...        ...             ...
# 214170  214170        0.257663
# 214171  214171        0.347823
# 214172  214172        0.257663
# 214173  214173        0.243630
# 214174  214174        0.347823
# 214175  214175        0.284747
# 214176  214176        0.257663
# 214177  214177        0.257663
# 214178  214178        0.257663
# 214179  214179        0.347823
# 214180  214180        0.257663
# 214181  214181        0.285040
# 214182  214182        0.284747
# 214183  214183        0.257663
# 214184  214184        0.257663
# 214185  214185        0.257663
# 214186  214186        0.257663
# 214187  214187        0.284747
# 214188  214188        0.257663
# 214189  214189        0.243630
# 214190  214190        0.243630
# 214191  214191        0.284747
# 214192  214192        0.284747
# 214193  214193        0.285040
# 214194  214194        0.285040
# 214195  214195        0.243630
# 214196  214196        0.243630
# 214197  214197        0.243630
# 214198  214198        0.257663
# 214199  214199        0.257663
#
# [214200 rows x 2 columns]
